# %%
# %pip install requests
# %pip install pandas
# %pip install boto3
# %pip install awswrangler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from requests) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from requests) (2024.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from requests) (1.26.19)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: boto3 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (1.34.145)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.145 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from boto3) (1.34.145)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from botocore<1.35.0,>=1.34.145->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from botocore<1.35.0,>=1.34.145->boto3) (1.26.19)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.145->boto3) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: awswrangler in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (3.9.0)
# Requirement already satisfied: botocore<2.0.0,>=1.23.32 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (1.34.145)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.4.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (4.12.2)
# Requirement already satisfied: boto3<2.0.0,>=1.20.32 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (1.34.145)
# Requirement already satisfied: numpy<2.0,>=1.18 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.2.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (2.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (17.0.0)
# Requirement already satisfied: packaging<25.0,>=21.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from awswrangler) (24.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from boto3<2.0.0,>=1.20.32->awswrangler) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from boto3<2.0.0,>=1.20.32->awswrangler) (0.10.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from botocore<2.0.0,>=1.23.32->awswrangler) (1.26.19)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from botocore<2.0.0,>=1.23.32->awswrangler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.23.32->awswrangler) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (1.26.4)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import boto3
import awswrangler as wr
import numpy

# %%
response = requests.get("https://restcountries.com/v3.1/all")

# %%
response.status_code
# Out:
# 200

# %%
response = response.json()

# %%
response[0]
# Out:
# {'name': {'common': 'South Georgia',
#   'official': 'South Georgia and the South Sandwich Islands',
#   'nativeName': {'eng': {'official': 'South Georgia and the South Sandwich Islands',
#     'common': 'South Georgia'}}},
#  'tld': ['.gs'],
#  'cca2': 'GS',
#  'ccn3': '239',
#  'cca3': 'SGS',
#  'independent': False,
#  'status': 'officially-assigned',
#  'unMember': False,
#  'currencies': {'SHP': {'name': 'Saint Helena pound', 'symbol': '£'}},
#  'idd': {'root': '+5', 'suffixes': ['00']},
#  'capital': ['King Edward Point'],
#  'altSpellings': ['GS', 'South Georgia and the South Sandwich Islands'],
#  'region': 'Antarctic',
#  'languages': {'eng': 'English'},
#  'translations': {'ara': {'official': 'جورجيا الجنوبية وجزر ساندوتش الجنوبية',
#    'common': 'جورجيا الجنوبية'},
#   'bre': {'official': 'Georgia ar Su hag Inizi Sandwich ar Su',
#    'common': 'Georgia ar Su hag Inizi Sandwich ar Su'},
#   'ces': {'official': 'Jižní Georgie a Jižní Sandwichovy ostrovy',
#    'common': 'Jižní Georgie a Jižní Sandwichovy ostrovy'},
#   'cym': {'official': 'South Georgia and the South Sandwich Islands',
#    'common': 'South Georgia'},
#   'deu': {'official': 'Südgeorgien und die Südlichen Sandwichinseln',
#    'common': 'Südgeorgien und die Südlichen Sandwichinseln'},
#   'est': {'official': 'Lõuna-Georgia ja Lõuna-Sandwichi saared',
#    'common': 'Lõuna-Georgia ja Lõuna-Sandwichi saared'},
#   'fin': {'official': 'Etelä-Georgia ja Eteläiset Sandwichsaaret',
#    'common': 'Etelä-Georgia ja Eteläiset Sandwichsaaret'},
#   'fra': {'official': 'Géorgie du Sud et les îles Sandwich du Sud',
#    'common': 'Géorgie du Sud-et-les Îles Sandwich du Sud'},
#   'hrv': {'official': 'Južna Džordžija i Otoci Južni Sendvič',
#    'common': 'Južna Georgija i otočje Južni Sandwich'},
#   'hun': {'official': 'Déli-Georgia és Déli-Sandwich-szigetek',
#    'common': 'Déli-Georgia és Déli-Sandwich-szigetek'},
#   'ita': {'official': 'Georgia del Sud e isole Sandwich del Sud',
#    'common': 'Georgia del Sud e Isole Sandwich Meridionali'},
#   'jpn': {'official': 'サウスジョージア·サウスサンドウィッチ諸島',
#    'common': 'サウスジョージア・サウスサンドウィッチ諸島'},
#   'kor': {'official': '조지아', 'common': '조지아'},
#   'nld': {'official': 'Zuid-Georgië en de Zuidelijke Sandwich-eilanden',
#    'common': 'Zuid-Georgia en Zuidelijke Sandwicheilanden'},
#   'per': {'official': 'جزایر جورجیای جنوبی و ساندویچ جنوبی',
#    'common': 'جزایر جورجیای جنوبی و ساندویچ جنوبی'},
#   'pol': {'official': 'Georgia Południowa i Sandwich Południowy',
#    'common': 'Georgia Południowa i Sandwich Południowy'},
#   'por': {'official': 'Geórgia do Sul e Sandwich do Sul',
#    'common': 'Ilhas Geórgia do Sul e Sandwich do Sul'},
#   'rus': {'official': 'Южная Георгия и Южные Сандвичевы острова',
#    'common': 'Южная Георгия и Южные Сандвичевы острова'},
#   'slk': {'official': 'Južná Georgia a Južné Sandwichove ostrovy',
#    'common': 'Južná Georgia a Južné Sandwichove ostrovy'},
#   'spa': {'official': 'Georgia del Sur y las Islas Sandwich del Sur',
#    'common': 'Islas Georgias del Sur y Sandwich del Sur'},
#   'srp': {'official': 'Јужна Џорџија и Јужна Сендвичка Острва',
#    'common': 'Јужна Џорџија и Јужна Сендвичка Острва'},
#   'swe': {'official': 'Sydgeorgien', 'common': 'Sydgeorgien'},
#   'tur': {'official': 'Güney Georgia ve Güney Sandwich Adaları',
#    'common': 'Güney Georgia ve Güney Sandwich Adaları'},
#   'urd': {'official': 'جنوبی جارجیا و جزائر جنوبی سینڈوچ',
#    'common': 'جنوبی جارجیا'},
#   'zho': {'official': '南乔治亚岛和南桑威奇群岛', 'common': '南乔治亚'}},
#  'latlng': [-54.5, -37.0],
#  'landlocked': False,
#  'area': 3903.0,
#  'demonyms': {'eng': {'f': 'South Georgian South Sandwich Islander',
#    'm': 'South Georgian South Sandwich Islander'}},
#  'flag': '🇬🇸',
#  'maps': {'googleMaps': 'https://goo.gl/maps/mJzdaBwKBbm2B81q9',
#   'openStreetMaps': 'https://www.openstreetmap.org/relation/1983629'},
#  'population': 30,
#  'car': {'signs': [''], 'side': 'right'},
#  'timezones': ['UTC-02:00'],
#  'continents': ['Antarctica'],
#  'flags': {'png': 'https://flagcdn.com/w320/gs.png',
#   'svg': 'https://flagcdn.com/gs.svg'},
#  'coatOfArms': {},
#  'startOfWeek': 'monday',
#  'capitalInfo': {'latlng': [-54.28, -36.5]}}

# %%
#extract the relevant columns 
extracted_datas = []
for item in response:
    name_info = item.get('name',{})
    country_name = name_info.get('common','')
    common_native_name = name_info.get('nativeName',{}).get('eng',{}).get('official','')
    official_country_name = name_info.get('official','')
    independence = item.get('independent','')
    united_Nation_members = item.get('unMember','')
    startOfWeek = item.get('startOfWeek','')
    capital = item.get('capital',[''])[0]
    region = item.get('region','')
    sub_region = item.get('subregion','')
    areas = item.get('area','')
    population = item.get('population','')
    continents = item.get('continents',[''])[0]
    languages = ', '.join(item.get('languages',{}).values())
    idd_info = item.get('idd',{})
    idd_root = idd_info.get('root','')
    idd_suffix = ''.join(idd_info.get('suffixes',[]))
    country_code = idd_root + idd_suffix
    currency_info = item.get('currencies',{})
    currency_code = next(iter(currency_info),'')
    currency_name = currency_info.get(currency_code,{}).get('name','')
    currency_symbol = currency_info.get(currency_code,{}).get('symbol','')
    
# appending the extracted data into the empty list created
    extracted_datas.append({
        'country_name': country_name,
        'common_native_name': common_native_name,
        'official_country_name': official_country_name,
        'independence': independence,
        'united_Nation_members': united_Nation_members,
        'startOfWeek': startOfWeek,
        'currency_name': currency_name,
        'currency_symbol':currency_symbol,
        'capital':capital,
        'region':region,
        'sub_region': sub_region,
        'languages':languages,
        'areas': areas,
        'population': population,
        'continents': continents,
        'currency_code':currency_code,
        'country_code': country_code
        
    })
# Converted to DataFrame for easier manipulation
df=pd.DataFrame(extracted_datas)
df
# Out:
#       country_name                            common_native_name  \
# 0    South Georgia  South Georgia and the South Sandwich Islands
# 1          Grenada                                       Grenada
# 2      Switzerland
# 3     Sierra Leone                      Republic of Sierra Leone
# 4          Hungary
# ..             ...                                           ...
# 245        Belgium
# 246         Israel
# 247    New Zealand                                   New Zealand
# 248      Nicaragua
# 249       Anguilla                                      Anguilla
#
#                             official_country_name independence  \
# 0    South Georgia and the South Sandwich Islands        False
# 1                                         Grenada         True
# 2                             Swiss Confederation         True
# 3                        Republic of Sierra Leone         True
# 4                                         Hungary         True
# ..                                            ...          ...
# 245                            Kingdom of Belgium         True
# 246                               State of Israel         True
# 247                                   New Zealand         True
# 248                         Republic of Nicaragua         True
# 249                                      Anguilla        False
#
#      united_Nation_members startOfWeek             currency_name  \
# 0                    False      monday        Saint Helena pound
# 1                     True      monday  Eastern Caribbean dollar
# 2                     True      monday               Swiss franc
# 3                     True      monday      Sierra Leonean leone
# 4                     True      monday          Hungarian forint
# ..                     ...         ...                       ...
# 245                   True      monday                      Euro
# 246                   True      sunday        Israeli new shekel
# 247                   True      monday        New Zealand dollar
# 248                   True      monday        Nicaraguan córdoba
# 249                  False      monday  Eastern Caribbean dollar
#
#     currency_symbol            capital     region                 sub_region  \
# 0                 £  King Edward Point  Antarctic
# 1                 $       St. George's   Americas                  Caribbean
# 2               Fr.               Bern     Europe             Western Europe
# 3                Le           Freetown     Africa             Western Africa
# 4                Ft           Budapest     Europe             Central Europe
# ..              ...                ...        ...                        ...
# 245               €           Brussels     Europe             Western Europe
# 246               ₪          Jerusalem       Asia               Western Asia
# 247               $         Wellington    Oceania  Australia and New Zealand
# 248              C$            Managua   Americas            Central America
# 249               $         The Valley   Americas                  Caribbean
#
#                                      languages     areas  population  \
# 0                                      English    3903.0          30
# 1                                      English     344.0      112519
# 2       French, Swiss German, Italian, Romansh   41284.0     8654622
# 3                                      English   71740.0     7976985
# 4                                    Hungarian   93028.0     9749763
# ..                                         ...       ...         ...
# 245                      German, French, Dutch   30528.0    11555997
# 246                             Arabic, Hebrew   20770.0     9216900
# 247  English, Māori, New Zealand Sign Language  270467.0     5084300
# 248                                    Spanish  130373.0     6624554
# 249                                    English      91.0       13452
#
#         continents currency_code country_code
# 0       Antarctica           SHP         +500
# 1    North America           XCD        +1473
# 2           Europe           CHF          +41
# 3           Africa           SLL         +232
# 4           Europe           HUF          +36
# ..             ...           ...          ...
# 245         Europe           EUR          +32
# 246           Asia           ILS         +972
# 247        Oceania           NZD          +64
# 248  North America           NIO         +505
# 249  North America           XCD        +1264
#
# [250 rows x 17 columns]

# %%
##writing to rds instance

# %%
pip install pandas sqlalchemy pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (2.0.31)
# Requirement already satisfied: pyodbc in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (5.1.0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/rukayatjimoh/Library/Python/3.9/lib/python/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp39-cp39-macosx_11_0_arm64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 3.6 MB/s eta 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
import boto3
import psycopg2

# %%
# Initialize a session using Boto3
session = boto3.Session(region_name='eu-central-1')

# %%
# Initialize the SSM client
ssm_client = session.client('ssm')

# %%
# Get the parameter value
parameter_name = 'DEC_hackathon_db_pwd'
parameter = ssm_client.get_parameter(Name=parameter_name, WithDecryption=True)
db_password = parameter['Parameter']['Value']

# %%
db_username = 'bimmy'
db_name = 'dec_hackathon_db'
db_host = 'dec-hackathon.c7a2yi4u263m.eu-central-1.rds.amazonaws.com' 
db_port = 5432

engine = create_engine(f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
# Write DataFrame to PostgreSQL table
df.to_sql('dec_hackathon_tb', engine, if_exists='replace', index=False)
# Out:
# 250

# %% [markdown]
# ### Analysis

# %%
#Countries that speaks French
French_countries = sum(df['languages'].str.contains('French'))
French_countries
# Out:
# 46

# %%
df[df['languages'].str.contains('French', na=False)]
# Out:
#                             country_name      common_native_name  \
# 2                            Switzerland
# 6                      Wallis and Futuna
# 9                            Ivory Coast
# 12                                 Benin
# 20                               Burundi
# 22                                France
# 25                                 Gabon
# 30                      Saint Barthélemy
# 31                              Guernsey   Bailiwick of Guernsey
# 37                               Senegal
# 50                                 Niger
# 55                               Réunion
# 56                              Djibouti
# 58                             Mauritius   Republic of Mauritius
# 75                                Monaco
# 77                               Lebanon
# 79                               Mayotte
# 84                            Madagascar
# 100  French Southern and Antarctic Lands
# 108                               Canada                  Canada
# 116            Saint Pierre and Miquelon
# 121                         Sint Maarten            Sint Maarten
# 123                           Luxembourg
# 133                                Haiti
# 136                    Equatorial Guinea
# 138                     French Polynesia
# 142                           Guadeloupe
# 146                             Cameroon    Republic of Cameroon
# 147                               Guinea
# 150                             DR Congo
# 153                        New Caledonia
# 154                              Vanuatu     Republic of Vanuatu
# 156                                 Togo
# 161                               Rwanda      Republic of Rwanda
# 179                        French Guiana
# 182             Central African Republic
# 183                         Burkina Faso
# 195                                 Mali
# 199                               Jersey     Bailiwick of Jersey
# 206                           Seychelles  Republic of Seychelles
# 210                           Martinique
# 233                              Comoros
# 238                                 Chad
# 240                         Saint Martin
# 244                Republic of the Congo
# 245                              Belgium
#
#                                  official_country_name independence  \
# 2                                  Swiss Confederation         True
# 6           Territory of the Wallis and Futuna Islands        False
# 9                            Republic of Côte d'Ivoire         True
# 12                                   Republic of Benin         True
# 20                                 Republic of Burundi         True
# 22                                     French Republic         True
# 25                                   Gabonese Republic         True
# 30                    Collectivity of Saint Barthélemy        False
# 31                               Bailiwick of Guernsey        False
# 37                                 Republic of Senegal         True
# 50                                   Republic of Niger         True
# 55                                      Réunion Island        False
# 56                                Republic of Djibouti         True
# 58                               Republic of Mauritius         True
# 75                              Principality of Monaco         True
# 77                                   Lebanese Republic         True
# 79                               Department of Mayotte        False
# 84                              Republic of Madagascar         True
# 100  Territory of the French Southern and Antarctic...        False
# 108                                             Canada         True
# 116                          Saint Pierre and Miquelon        False
# 121                                       Sint Maarten        False
# 123                          Grand Duchy of Luxembourg         True
# 133                                  Republic of Haiti         True
# 136                      Republic of Equatorial Guinea         True
# 138                                   French Polynesia        False
# 142                                         Guadeloupe        False
# 146                               Republic of Cameroon         True
# 147                                 Republic of Guinea         True
# 150                   Democratic Republic of the Congo         True
# 153                                      New Caledonia        False
# 154                                Republic of Vanuatu         True
# 156                                  Togolese Republic         True
# 161                                 Republic of Rwanda         True
# 179                                             Guiana        False
# 182                           Central African Republic         True
# 183                                       Burkina Faso         True
# 195                                   Republic of Mali         True
# 199                                Bailiwick of Jersey        False
# 206                             Republic of Seychelles         True
# 210                                         Martinique        False
# 233                               Union of the Comoros         True
# 238                                   Republic of Chad         True
# 240                                       Saint Martin        False
# 244                              Republic of the Congo         True
# 245                                 Kingdom of Belgium         True
#
#      united_Nation_members startOfWeek                  currency_name  \
# 2                     True      monday                    Swiss franc
# 6                    False      monday                      CFP franc
# 9                     True      monday         West African CFA franc
# 12                    True      monday         West African CFA franc
# 20                    True      monday                Burundian franc
# 22                    True      monday                           Euro
# 25                    True      monday      Central African CFA franc
# 30                   False      monday                           Euro
# 31                   False      monday                  British pound
# 37                    True      monday         West African CFA franc
# 50                    True      monday         West African CFA franc
# 55                   False      monday                           Euro
# 56                    True      monday               Djiboutian franc
# 58                    True      monday                Mauritian rupee
# 75                    True      monday                           Euro
# 77                    True      monday                 Lebanese pound
# 79                   False      monday                           Euro
# 84                    True      monday                Malagasy ariary
# 100                  False      monday                           Euro
# 108                   True      sunday                Canadian dollar
# 116                  False      monday                           Euro
# 121                  False      monday  Netherlands Antillean guilder
# 123                   True      monday                           Euro
# 133                   True      monday                 Haitian gourde
# 136                   True      monday      Central African CFA franc
# 138                  False      monday                      CFP franc
# 142                  False      monday                           Euro
# 146                   True      monday      Central African CFA franc
# 147                   True      monday                  Guinean franc
# 150                   True      monday                Congolese franc
# 153                  False      monday                      CFP franc
# 154                   True      monday                   Vanuatu vatu
# 156                   True      monday         West African CFA franc
# 161                   True      monday                  Rwandan franc
# 179                  False      monday                           Euro
# 182                   True      monday      Central African CFA franc
# 183                   True      monday         West African CFA franc
# 195                   True      monday         West African CFA franc
# 199                  False      monday                  British pound
# 206                   True      monday              Seychellois rupee
# 210                  False      monday                           Euro
# 233                   True      monday                 Comorian franc
# 238                   True      monday      Central African CFA franc
# 240                  False      monday                           Euro
# 244                   True      monday      Central African CFA franc
# 245                   True      monday                           Euro
#
#     currency_symbol            capital     region       sub_region  \
# 2               Fr.               Bern     Europe   Western Europe
# 6                 ₣           Mata-Utu    Oceania        Polynesia
# 9                Fr       Yamoussoukro     Africa   Western Africa
# 12               Fr         Porto-Novo     Africa   Western Africa
# 20               Fr             Gitega     Africa   Eastern Africa
# 22                €              Paris     Europe   Western Europe
# 25               Fr         Libreville     Africa    Middle Africa
# 30                €           Gustavia   Americas        Caribbean
# 31                £     St. Peter Port     Europe  Northern Europe
# 37               Fr              Dakar     Africa   Western Africa
# 50               Fr             Niamey     Africa   Western Africa
# 55                €        Saint-Denis     Africa   Eastern Africa
# 56               Fr           Djibouti     Africa   Eastern Africa
# 58                ₨         Port Louis     Africa   Eastern Africa
# 75                €             Monaco     Europe   Western Europe
# 77              ل.ل             Beirut       Asia     Western Asia
# 79                €          Mamoudzou     Africa   Eastern Africa
# 84               Ar       Antananarivo     Africa   Eastern Africa
# 100               €  Port-aux-Français  Antarctic
# 108               $             Ottawa   Americas    North America
# 116               €       Saint-Pierre   Americas    North America
# 121               ƒ        Philipsburg   Americas        Caribbean
# 123               €         Luxembourg     Europe   Western Europe
# 133               G     Port-au-Prince   Americas        Caribbean
# 136              Fr             Malabo     Africa    Middle Africa
# 138               ₣            Papeetē    Oceania        Polynesia
# 142               €        Basse-Terre   Americas        Caribbean
# 146              Fr            Yaoundé     Africa    Middle Africa
# 147              Fr            Conakry     Africa   Western Africa
# 150              FC           Kinshasa     Africa    Middle Africa
# 153               ₣             Nouméa    Oceania        Melanesia
# 154              Vt          Port Vila    Oceania        Melanesia
# 156              Fr               Lomé     Africa   Western Africa
# 161              Fr             Kigali     Africa   Eastern Africa
# 179               €            Cayenne   Americas    South America
# 182              Fr             Bangui     Africa    Middle Africa
# 183              Fr        Ouagadougou     Africa   Western Africa
# 195              Fr             Bamako     Africa   Western Africa
# 199               £       Saint Helier     Europe  Northern Europe
# 206               ₨           Victoria     Africa   Eastern Africa
# 210               €     Fort-de-France   Americas        Caribbean
# 233              Fr             Moroni     Africa   Eastern Africa
# 238              Fr          N'Djamena     Africa    Middle Africa
# 240               €            Marigot   Americas        Caribbean
# 244              Fr        Brazzaville     Africa    Middle Africa
# 245               €           Brussels     Europe   Western Europe
#
#                                        languages       areas  population  \
# 2         French, Swiss German, Italian, Romansh    41284.00     8654622
# 6                                         French      142.00       11750
# 9                                         French   322463.00    26378275
# 12                                        French   112622.00    12123198
# 20                               French, Kirundi    27834.00    11890781
# 22                                        French   551695.00    67391582
# 25                                        French   267668.00     2225728
# 30                                        French       21.00        4255
# 31                  English, French, Guernésiais       78.00       62999
# 37                                        French   196722.00    16743930
# 50                                        French  1267000.00    24206636
# 55                                        French     2511.00      840974
# 56                                Arabic, French    23200.00      988002
# 58             English, French, Mauritian Creole     2040.00     1265740
# 75                                        French        2.02       39244
# 77                                Arabic, French    10452.00     6825442
# 79                                        French      374.00      226915
# 84                              French, Malagasy   587041.00    27691019
# 100                                       French     7747.00         400
# 108                              English, French  9984670.00    38005238
# 116                                       French      242.00        6069
# 121                       English, French, Dutch       34.00       40812
# 123                German, French, Luxembourgish     2586.00      632275
# 133                       French, Haitian Creole    27750.00    11402533
# 136                  French, Portuguese, Spanish    28051.00     1402985
# 138                                       French     4167.00      280904
# 142                                       French     1628.00      400132
# 146                              English, French   475442.00    26545864
# 147                                       French   245857.00    13132792
# 150  French, Kikongo, Lingala, Tshiluba, Swahili  2344858.00   108407721
# 153                                       French    18575.00      271960
# 154                     Bislama, English, French    12189.00      307150
# 156                                       French    56785.00     8278737
# 161                 English, French, Kinyarwanda    26338.00    12952209
# 179                                       French    83534.00      254541
# 182                                French, Sango   622984.00     4829764
# 183                                       French   272967.00    20903278
# 195                                       French  1240192.00    20250834
# 199                    English, French, Jèrriais      116.00      100800
# 206          Seychellois Creole, English, French      452.00       98462
# 210                                       French     1128.00      378243
# 233                     Arabic, French, Comorian     1862.00      869595
# 238                               Arabic, French  1284000.00    16425859
# 240                                       French       53.00       38659
# 244                     French, Kikongo, Lingala   342000.00     5657000
# 245                        German, French, Dutch    30528.00    11555997
#
#         continents currency_code country_code
# 2           Europe           CHF          +41
# 6          Oceania           XPF         +681
# 9           Africa           XOF         +225
# 12          Africa           XOF         +229
# 20          Africa           BIF         +257
# 22          Europe           EUR          +33
# 25          Africa           XAF         +241
# 30   North America           EUR         +590
# 31          Europe           GBP          +44
# 37          Africa           XOF         +221
# 50          Africa           XOF         +227
# 55          Africa           EUR         +262
# 56          Africa           DJF         +253
# 58          Africa           MUR         +230
# 75          Europe           EUR         +377
# 77            Asia           LBP         +961
# 79          Africa           EUR         +262
# 84          Africa           MGA         +261
# 100     Antarctica           EUR         +262
# 108  North America           CAD           +1
# 116  North America           EUR         +508
# 121  North America           ANG        +1721
# 123         Europe           EUR         +352
# 133  North America           HTG         +509
# 136         Africa           XAF         +240
# 138        Oceania           XPF         +689
# 142  North America           EUR         +590
# 146         Africa           XAF         +237
# 147         Africa           GNF         +224
# 150         Africa           CDF         +243
# 153        Oceania           XPF         +687
# 154        Oceania           VUV         +678
# 156         Africa           XOF         +228
# 161         Africa           RWF         +250
# 179  South America           EUR         +594
# 182         Africa           XAF         +236
# 183         Africa           XOF         +226
# 195         Africa           XOF         +223
# 199         Europe           GBP          +44
# 206         Africa           SCR         +248
# 210  North America           EUR         +596
# 233         Africa           KMF         +269
# 238         Africa           XAF         +235
# 240  North America           EUR         +590
# 244         Africa           XAF         +242
# 245         Europe           EUR          +32

# %%
#Countries that speaks French
French_countries = sum(df['languages'].str.contains('English'))
French_countries
# Out:
# 91

# %%
#Countries that speaks French
country_EUR = sum(df['currency_code'].str.contains('EUR'))
country_EUR
# Out:
# 36
